# %%
import pickle as pkl
with open("/home/r/Scripts/2023-tianzhibei-competition/mmrotate/work_dirs/oriented_rcnn_van-base-1x-dota/test_results.pkl", "rb") as f:
    data= pkl.load(f)
for d in data:
    print(d)
# Out:
# {'ori_shape': (1024, 1024), 'img_shape': (1024, 1024), 'img_path': 'data/mini_dota/trainval/images/P0001__1024__0___4750.png', 'pad_shape': (1024, 1024), 'scale_factor': (1.0, 1.0), 'batch_input_shape': (1024, 1024), 'img_id': 'P0001__1024__0___4750', 'gt_instances': {'bboxes': tensor([[4.5150e+02, 2.0000e+02, 2.7500e+02, 2.2000e+01, 0.0000e+00],
#         [5.6354e+02, 1.7760e+02, 5.3387e+01, 2.3788e+01, 1.8866e-02],
#         [4.5471e+02, 6.0518e+02, 2.5058e+01, 3.0107e+02, 1.3871e+00],
#         [5.6566e+02, 5.6140e+02, 2.2050e+01, 4.6530e+01, 1.4198e+00]]), 'labels': tensor([12,  6, 12,  6])}, 'pred_instances': {'bboxes': tensor([[ 5.6162e+02,  1.8106e+02,  4.3768e+01,  2.3705e+01, -4.4569e-02],
#         [ 5.6567e+02,  5.6205e+02,  4.4873e+01,  2.3997e+01, -1.4098e-01],
#         [ 4.5597e+02,  6.0631e+02,  3.0337e+02,  1.8508e+01, -1.8668e-01],
#         [ 4.5037e+02,  2.0079e+02,  2.7993e+02,  1.8777e+01, -8.0681e-04],
# ...
